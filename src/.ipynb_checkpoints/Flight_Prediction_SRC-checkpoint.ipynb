# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
import re as re
import requests
import datetime
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

sb.set() # set the default Seaborn style for graphics

# %%
flightData_economy = pd.read_csv('https://raw.githubusercontent.com/chongwei49/IE0005-DSAI-Group-Barley/master/dataset/economy.csv')
flightData_business = pd.read_csv('https://raw.githubusercontent.com/chongwei49/IE0005-DSAI-Group-Barley/master/dataset/business.csv')

flightData_economy["class"] = "Economy"
flightData_business["class"] = "Business"

flightData_economy['date'] = pd.to_datetime(flightData_economy['date'], format='%d/%m/%Y')
flightData_economy['dayOfWeek'] = pd.to_datetime(flightData_economy["date"].dt.strftime('%Y-%m-%d')).dt.day_name()
flightData_economy['days_left'] = (flightData_economy["date"] - datetime.datetime.strptime('2022-02-10', '%Y-%m-%d')).dt.days

flightData_business['date'] = pd.to_datetime(flightData_business['date'], format='%d-%m-%Y')
flightData_business['dayOfWeek'] = pd.to_datetime(flightData_business["date"].dt.strftime('%Y-%m-%d')).dt.day_name()
flightData_business['days_left'] = (flightData_business["date"] - datetime.datetime.strptime('2022-02-10', '%Y-%m-%d')).dt.days

flightData = pd.concat([flightData_economy, flightData_business], ignore_index=True)
flightData.reset_index(drop=True)
#flightData.to_csv(r'C:\Users\Chong\OneDrive\Documents\GitHub\IE0005-DSAI-Group-Barley\dataset\export_dataframe.csv', index = None, header=True) 
#flightData = pd.read_csv('https://raw.githubusercontent.com/chongwei49/IE0005-DSAI-Group-Barley/master/dataset/Clean_Dataset.csv')
flightData
# Out:
#              date   airline ch_code  num_code dep_time     from time_taken  \
# 0      2022-02-11  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1      2022-02-11  SpiceJet      SG      8157     6:20    Delhi    02h 20m
# 2      2022-02-11   AirAsia      I5       764     4:25    Delhi    02h 10m
# 3      2022-02-11   Vistara      UK       995    10:20    Delhi    02h 15m
# 4      2022-02-11   Vistara      UK       963     8:50    Delhi    02h 20m
# ...           ...       ...     ...       ...      ...      ...        ...
# 300256 2022-03-31   Vistara      UK       822    09:45  Chennai    10h 05m
# 300257 2022-03-31   Vistara      UK       826    12:30  Chennai    10h 25m
# 300258 2022-03-31   Vistara      UK       832    07:05  Chennai    13h 50m
# 300259 2022-03-31   Vistara      UK       828    07:00  Chennai    10h 00m
# 300260 2022-03-31   Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# 1                                               non-stop      8:40     Mumbai
# 2                                               non-stop      6:35     Mumbai
# 3                                               non-stop     12:35     Mumbai
# 4                                               non-stop     11:10     Mumbai
# ...                                                   ...      ...        ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#          price     class dayOfWeek  days_left
# 0        5,953   Economy    Friday          1
# 1        5,953   Economy    Friday          1
# 2        5,956   Economy    Friday          1
# 3        5,955   Economy    Friday          1
# 4        5,955   Economy    Friday          1
# ...        ...       ...       ...        ...
# 300256  69,265  Business  Thursday         49
# 300257  77,105  Business  Thursday         49
# 300258  79,099  Business  Thursday         49
# 300259  81,585  Business  Thursday         49
# 300260  81,585  Business  Thursday         49
#
# [300261 rows x 14 columns]

# %%
flightData['flight'] = flightData['ch_code'].astype(str) + '-' + flightData['num_code'].astype(str)

flightData['stop'] = flightData['stop'].str.split(r'\n').str.get(0) #To clean 'stop' column

flightData['price'] = flightData['price'].str.replace(',', '') #To clean 'price' column
flightData['price'] = flightData['price'].astype('int64')

flightData['dep_time'] = flightData['dep_time'].str.replace(':', '') #To clean 'dep_time' column
flightData['dep_time'] = flightData['dep_time'].str.zfill(4) #To show time in HHMM format

flightData['arr_time'] = flightData['arr_time'].str.replace(':', '') #To clean 'arr_time' column
flightData['arr_time'] = flightData['arr_time'].str.zfill(4) #To show time in HHMM format

flightData['time_taken'] = flightData['time_taken'].str.replace('h','')
flightData['time_taken'] = flightData['time_taken'].str.replace('m','')
flightData['time_taken'] = (pd.to_numeric(flightData['time_taken'].str.split(' ').str.get(0), downcast="integer")*60.0) + pd.to_numeric(flightData['time_taken'].str.split(' ').str.get(1), downcast="integer")

def modify_stop(row):
  if "non-stop" in row['stop']:
    return 'zero'
  elif "1-stop" in row['stop']:
    return 'one'
  elif "2+-stop" in row['stop']:
    return 'two_or_more'
  else:
    return int(re.search(r'\d+', row['stop']).group())

flightData["stop"] = flightData.apply(modify_stop, axis=1)

# %%
def find_day_period_dep(row):
  # Early Morning 4am-8am
  # Morning 8am-12pm
  # Afternoon 12pm-4pm
  # Evening 4pm-8pm
  # Night 8pm-12am
  # Late Night 12am-4am
    x = int(row["dep_time"])
    if(x>400 and x<=800):
      return "Early Morning"
    elif(x>800 and x<=1200):
      return "Morning"
    elif(x>1200 and x<=1600):
      return "Afternoon"
    elif(x>1600 and x<=2000):
      return "Evening"
    elif(x>2000 and x<=2400):
      return "Night" 
    else:
      return "Late Night"

def find_day_period_arrival(row):
  # Early Morning 4am-8am
  # Morning 8am-12pm
  # Afternoon 12pm-4pm
  # Evening 4pm-8pm
  # Night 8pm-12am
  # Late Night 12am-4am
    x = int(row["arr_time"])
    if(x>400 and x<=800):
      return "Early Morning"
    elif(x>800 and x<=1200):
      return "Morning"
    elif(x>1200 and x<=1600):
      return "Afternoon"
    elif(x>1600 and x<=2000):
      return "Evening"
    elif(x>2000 and x<=2400):
      return "Night" 
    else:
      return "Late Night"





flightData["departure_time"] = flightData.apply(find_day_period_dep, axis=1)
flightData["arrival_time"] = flightData.apply(find_day_period_arrival, axis=1)

flightData = flightData.rename(columns={'from': 'source_city', 'to': 'destination_city', 'stop': 'stops', 'time_taken': 'duration'})
flightData.drop(columns=['dep_time', 'arr_time','ch_code', 'num_code', 'date'], axis=1, inplace=True) 
flightData
# Out:
#          airline source_city  duration stops destination_city  price  \
# 0       SpiceJet       Delhi     130.0  zero           Mumbai   5953
# 1       SpiceJet       Delhi     140.0  zero           Mumbai   5953
# 2        AirAsia       Delhi     130.0  zero           Mumbai   5956
# 3        Vistara       Delhi     135.0  zero           Mumbai   5955
# 4        Vistara       Delhi     140.0  zero           Mumbai   5955
# ...          ...         ...       ...   ...              ...    ...
# 300256   Vistara     Chennai     605.0   one        Hyderabad  69265
# 300257   Vistara     Chennai     625.0   one        Hyderabad  77105
# 300258   Vistara     Chennai     830.0   one        Hyderabad  79099
# 300259   Vistara     Chennai     600.0   one        Hyderabad  81585
# 300260   Vistara     Chennai     605.0   one        Hyderabad  81585
#
#            class dayOfWeek  days_left   flight departure_time   arrival_time
# 0        Economy    Friday          1  SG-8709        Evening          Night
# 1        Economy    Friday          1  SG-8157  Early Morning        Morning
# 2        Economy    Friday          1   I5-764  Early Morning  Early Morning
# 3        Economy    Friday          1   UK-995        Morning      Afternoon
# 4        Economy    Friday          1   UK-963        Morning        Morning
# ...          ...       ...        ...      ...            ...            ...
# 300256  Business  Thursday         49   UK-822        Morning        Evening
# 300257  Business  Thursday         49   UK-826      Afternoon          Night
# 300258  Business  Thursday         49   UK-832  Early Morning          Night
# 300259  Business  Thursday         49   UK-828  Early Morning        Evening
# 300260  Business  Thursday         49   UK-822        Morning        Evening
#
# [300261 rows x 12 columns]

# %%
print("Data type : ", type(flightData))
print("Data dims : ", flightData.shape)
print(flightData.dtypes)
#flightData.to_csv(r'C:\Users\Chong\OneDrive\Documents\GitHub\IE0005-DSAI-Group-Barley\dataset\export_dataframe.csv', index = None, header=True)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (300261, 12)
# airline              object
# source_city          object
# duration            float64
# stops                object
# destination_city     object
# price                 int64
# class                object
# dayOfWeek            object
# days_left             int64
# flight               object
# departure_time       object
# arrival_time         object
# dtype: object

# %%
# A Quick Information abou the Data
flightData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300261 non-null  object
#  1   source_city       300261 non-null  object
#  2   duration          300261 non-null  float64
#  3   stops             300261 non-null  object
#  4   destination_city  300261 non-null  object
#  5   price             300261 non-null  int64
#  6   class             300261 non-null  object
#  7   dayOfWeek         300261 non-null  object
#  8   days_left         300261 non-null  int64
#  9   flight            300261 non-null  object
#  10  departure_time    300261 non-null  object
#  11  arrival_time      300261 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 27.5+ MB

# %%
# Stastical Description of Data
flightData.describe()
# Out:
#             duration          price      days_left
# count  300261.000000  300261.000000  300261.000000
# mean      733.065416   20883.717666      26.004473
# std       431.576241   22695.911266      13.560985
# min        50.000000    1105.000000       1.000000
# 25%       405.000000    4783.000000      15.000000
# 50%       675.000000    7425.000000      26.000000
# 75%       970.000000   42521.000000      38.000000
# max      2990.000000  123071.000000      49.000000

# %%
# Find correlation variables (non-object varaibles)
flightData.corr()
# Out:
#            duration     price  days_left
# duration   1.000000  0.204472  -0.039106
# price      0.204472  1.000000  -0.091917
# days_left -0.039106 -0.091917   1.000000

# %%
flightData1=flightData.groupby(['flight','airline'],as_index=False).count()
flightData1.airline.value_counts()
# Out:
# Indigo       704
# Air India    218
# GO FIRST     205
# SpiceJet     186
# Vistara      133
# AirAsia      115
# Trujet         4
# StarAir        4
# Name: airline, dtype: int64

# %%
flightData = flightData[~flightData['airline'].str.contains("Trujet")]
flightData = flightData[~flightData['airline'].str.contains("StarAir")]
flightData
# Out:
#          airline source_city  duration stops destination_city  price  \
# 0       SpiceJet       Delhi     130.0  zero           Mumbai   5953
# 1       SpiceJet       Delhi     140.0  zero           Mumbai   5953
# 2        AirAsia       Delhi     130.0  zero           Mumbai   5956
# 3        Vistara       Delhi     135.0  zero           Mumbai   5955
# 4        Vistara       Delhi     140.0  zero           Mumbai   5955
# ...          ...         ...       ...   ...              ...    ...
# 300256   Vistara     Chennai     605.0   one        Hyderabad  69265
# 300257   Vistara     Chennai     625.0   one        Hyderabad  77105
# 300258   Vistara     Chennai     830.0   one        Hyderabad  79099
# 300259   Vistara     Chennai     600.0   one        Hyderabad  81585
# 300260   Vistara     Chennai     605.0   one        Hyderabad  81585
#
#            class dayOfWeek  days_left   flight departure_time   arrival_time
# 0        Economy    Friday          1  SG-8709        Evening          Night
# 1        Economy    Friday          1  SG-8157  Early Morning        Morning
# 2        Economy    Friday          1   I5-764  Early Morning  Early Morning
# 3        Economy    Friday          1   UK-995        Morning      Afternoon
# 4        Economy    Friday          1   UK-963        Morning        Morning
# ...          ...       ...        ...      ...            ...            ...
# 300256  Business  Thursday         49   UK-822        Morning        Evening
# 300257  Business  Thursday         49   UK-826      Afternoon          Night
# 300258  Business  Thursday         49   UK-832  Early Morning          Night
# 300259  Business  Thursday         49   UK-828  Early Morning        Evening
# 300260  Business  Thursday         49   UK-822        Morning        Evening
#
# [300159 rows x 12 columns]

# %%
print("Table after dropping outlying Airlines")
flightData1=flightData.groupby(['flight','airline'],as_index=False).count()
flightData1.airline.value_counts()
# Out:
# Table after dropping outlying Airlines
# Indigo       704
# Air India    218
# GO FIRST     205
# SpiceJet     186
# Vistara      133
# AirAsia      115
# Name: airline, dtype: int64

# %%
# Find correlation variables (non-object varaibles)
flightData.corr()
# Out:
#            duration     price  days_left
# duration   1.000000  0.204226  -0.039141
# price      0.204226  1.000000  -0.091939
# days_left -0.039141 -0.091939   1.000000

# %%
sb.heatmap(flightData.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f", cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %%
plt.style.use('bmh')
plt.figure(figsize=(8,5))
sb.countplot(flightData1['airline'],palette='hls')
plt.title('Flights Count of Different Airlines',fontsize=15)
plt.xlabel('Airline',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %% [markdown]
# ### Indigo has the highest flight counts, which means it operates the most number of routes within india

# %%
flightData2=flightData.groupby(['flight','airline','class'],as_index=False).count()
flightData2['class'].value_counts()
# Out:
# Economy     1560
# Business     295
# Name: class, dtype: int64

# %%
plt.figure(figsize=(8,6))
flightData2['class'].value_counts().plot(kind='pie',textprops={'color':'black'},autopct='%.2f',cmap='Set3')
plt.title('Classes of Different Airlines',fontsize=15)
plt.legend(['Economy','Business'])
plt.show()

# %% [markdown]
# ### Most airlines has more Economy flights than business

# %%
plt.figure(figsize=(15,5))
sb.boxplot(x=flightData['airline'],y=flightData['price'],palette='hls')
plt.title('Price vs Airlines',fontsize=15)
plt.xlabel('Airline',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Airlines]
# ##### 1.We can see that Vistara has the highest price range
# ##### 2.Vistara and Air India has higher price range compared to the 4 other airlines
# ##### 3.SpiceJet, AirAsia, GO FIRST and Indigo has similar price range

# %%
plt.figure(figsize=(10,5))
sb.boxplot(x='class',y='price',data=flightData,palette='hls')
plt.title('Class Vs Ticket Price',fontsize=15)
plt.xlabel('Class',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Class]
# ##### 1.Bussiness Class has a higher price range compared to Economy Class

# %%
plt.figure(figsize=(10,5))
sb.boxplot(x='stops',y='price',data=flightData,palette='hls')
plt.title('Stops Vs Ticket Price',fontsize=15)
plt.xlabel('Stops',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Stops]
# ##### 1. Flights that stops once, has highest price range

# %%
plt.figure(figsize=(24,10))
plt.subplot(1,2,1)
sb.boxplot(x='departure_time',y='price',data=flightData)
plt.title('Departure Time Vs Ticket Price',fontsize=20)
plt.xlabel('Departure Time',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.subplot(1,2,2)
sb.boxplot(x='arrival_time',y='price',data=flightData,palette='hls')
plt.title('Arrival Time Vs Ticket Price',fontsize=20)
plt.xlabel('Arrival Time',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Departure Time]
# ##### 1. Ticket Price is higher for the Flights when the Departure Time is at Night
# ##### 2. Ticket Price is almost equal for flights Having Departure time at Early_morning , Morning and Evening
# ##### 3. Ticket Price is lower for the Flights Having Departure Time at Late_night

# %% [markdown]
# ### [Price against Arrival Time]
# ##### 1. Ticket Price is higher for the Flights when the Arrival Time is at Evening
# ##### 2. Ticket Price is almost equal for flights Having Arrival time is at Morning and Night
# ##### 3. Ticket Price is lower for the Flights Having Arrival Time at Late_night as same as Departure Time

# %%
plt.figure(figsize=(24,10))
plt.subplot(1,2,1)
sb.boxplot(x='source_city',y='price',data=flightData)
plt.title('Source City Vs Ticket Price',fontsize=20)
plt.xlabel('Source City',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.subplot(1,2,2)
sb.boxplot(x='destination_city',y='price',data=flightData,palette='hls')
plt.title('Destination City Vs Ticket Price',fontsize=20)
plt.xlabel('Destination City',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Source City]
# ##### 1. Ticket Price is higher for the Flights whose Source City is Kolkata
# ##### 2. Ticket Price is almost equal for flights Having Source Cities as Mumbai and chennai , Hyderabad and Bangalore
# ##### 3. Ticket Price is lower for the Flights Having Source City as Delhi

# %% [markdown]
# ### [Price against Destination City]
# ##### 1. Ticket Price is higher for the Flights whose Destination City is kolkata and Chennai
# ##### 2. Ticket Price is almost equal for flights Having Destination Cities as Mumbai and Bangalore
# ##### 3. Ticket Price is lower for the Flights Having Destination City as Delhi

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=flightData,x='duration',y='price',hue='class',palette='hls')
plt.title('Ticket Price Versus Flight Duration Based on Class',fontsize=20)
plt.xlabel('Duration',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Duration(Hours) based on Class]
# ##### 1. With increase in Duration, the Ticket Price is also Increases In both the Economy and Business classes

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=flightData,x='departure_time',y='price',hue='dayOfWeek',palette='hls')
plt.title('Ticket Price Versus Departure Time based on Day of Week',fontsize=20)
plt.xlabel('Departure Period',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=flightData,x='days_left',y='price',color='blue')
plt.title('Days Left For Departure Versus Ticket Price',fontsize=20)
plt.xlabel('Days Left for Departure',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ### [Price against Days Left for Departure]
# ##### 1. Based on the graph, price gradually increases as days left for departure decreases. However price will peak a few days before departure before decreasing drastically.

# %%
flightData.groupby(['flight','source_city','destination_city','airline','class'],as_index=False).count().groupby(['source_city','destination_city'],as_index=False)['flight'].count().head(10)
# Out:
#   source_city destination_city  flight
# 0   Bangalore          Chennai     106
# 1   Bangalore            Delhi     227
# 2   Bangalore        Hyderabad     132
# 3   Bangalore          Kolkata     171
# 4   Bangalore           Mumbai     175
# 5     Chennai        Bangalore      69
# 6     Chennai            Delhi     105
# 7     Chennai        Hyderabad      82
# 8     Chennai          Kolkata     110
# 9     Chennai           Mumbai      94

# %% [markdown]
# ### Total number of Flights from one city to another

# %%
flightData.groupby(['airline','source_city','destination_city'],as_index=False)['price'].mean()
# Out:
#        airline source_city destination_city         price
# 0    Air India   Bangalore          Chennai  26765.567702
# 1    Air India   Bangalore            Delhi  20699.099886
# 2    Air India   Bangalore        Hyderabad  23395.956912
# 3    Air India   Bangalore          Kolkata  29105.826259
# 4    Air India   Bangalore           Mumbai  25625.530802
# ..         ...         ...              ...           ...
# 172    Vistara      Mumbai        Bangalore  35029.880315
# 173    Vistara      Mumbai          Chennai  32181.946251
# 174    Vistara      Mumbai            Delhi  26402.695114
# 175    Vistara      Mumbai        Hyderabad  29497.578017
# 176    Vistara      Mumbai          Kolkata  35223.862417
#
# [177 rows x 4 columns]

# %% [markdown]
# ### Average Price of different Airlnes from Source city to Destination city

# %% [markdown]
# # -------------------------------------------Prediction----------------------------------------------------

# %%
# Creating a Back up File
df = flightData.copy()
df = df.reset_index()
df_bk=df.copy()

# %%
# Coverting the labels into a numeric form using Label Encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtype=='object':
        df[col]=le.fit_transform(df[col])

# %%
# storing the Dependent Variables in X and Independent Variable in Y
x=df.drop(['price'],axis=1)
y=df['price']

# %%
# Splitting the Data into Training set and Testing Set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((210111, 12), (90048, 12), (210111,), (90048,))

# %%
# Scaling the values to convert the int values to Machine Languages
from sklearn.preprocessing import MinMaxScaler
mmscaler=MinMaxScaler(feature_range=(0,1))
x_train=mmscaler.fit_transform(x_train)
x_test=mmscaler.fit_transform(x_test)
x_train=pd.DataFrame(x_train)
x_test=pd.DataFrame(x_test)

# %%
a={'Model Name':[], 'Mean_Absolute_Error_MAE':[] ,'Adj_R_Square':[] ,'Root_Mean_Squared_Error_RMSE':[] ,'Mean_Absolute_Percentage_Error_MAPE':[] ,'Mean_Squared_Error_MSE':[] ,'Root_Mean_Squared_Log_Error_RMSLE':[] ,'R2_score':[]}
Results=pd.DataFrame(a)
Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, Mean_Absolute_Error_MAE, Adj_R_Square, Root_Mean_Squared_Error_RMSE, Mean_Absolute_Percentage_Error_MAPE, Mean_Squared_Error_MSE, Root_Mean_Squared_Log_Error_RMSLE, R2_score]
# Index: []

# %%
# Build the Regression / Regressor models

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modelrfr = RandomForestRegressor()
modelETR = ExtraTreesRegressor()

# Evalution matrix for all the algorithms

MM = [modelmlg, modelrfr, modelETR]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(x_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
    #------------------------------------------------------------
# Out:
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 4668.562
# Mean Squared Error (MSE): 49111903.178
# Root Mean Squared Error (RMSE): 7007.989
# R2_score: 0.904425
# Root Mean Squared Log Error (RMSLE): 8.855
# Mean Absolute Percentage Error (MAPE): 44.7 %
# Adj R Square:  0.904421
# ------------------------------------------------------------------------------------------------------------
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 805.214
# Mean Squared Error (MSE): 4496381.932
# Root Mean Squared Error (RMSE): 2120.467
# R2_score: 0.99125
# Root Mean Squared Log Error (RMSLE): 7.659
# Mean Absolute Percentage Error (MAPE): 5.44 %
# Adj R Square:  0.99125
# ------------------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 802.758
# Mean Squared Error (MSE): 4497944.724
# Root Mean Squared Error (RMSE): 2120.836
# R2_score: 0.991247
# Root Mean Squared Log Error (RMSLE): 7.66
# Mean Absolute Percentage Error (MAPE): 5.56 %
# Adj R Square:  0.991247
# ------------------------------------------------------------------------------------------------------------

# %%
Results
# Out:
#                                           Model Name  Mean_Absolute_Error_MAE  \
# 0                                 LinearRegression()              4668.562447
# 1  (DecisionTreeRegressor(max_features='auto', ra...               805.213942
# 2  (ExtraTreeRegressor(random_state=1826099873), ...               802.757557
#
#    Adj_R_Square  Root_Mean_Squared_Error_RMSE  \
# 0      0.904421                   7007.988526
# 1      0.991250                   2120.467385
# 2      0.991247                   2120.835855
#
#    Mean_Absolute_Percentage_Error_MAPE  Mean_Squared_Error_MSE  \
# 0                            44.695236            4.911190e+07
# 1                             5.436641            4.496382e+06
# 2                             5.557894            4.497945e+06
#
#    Root_Mean_Squared_Log_Error_RMSLE  R2_score
# 0                           8.854806  0.904425
# 1                           7.659392  0.991250
# 2                           7.659566  0.991247

# %%
models=['LinearRegression','ExtraTreesRegressor','RandomForestRegressor']
result=pd.DataFrame({'Model_Name':models})
result['R2_score']=Results['R2_score']
result['Adj_R_Square']=Results['Adj_R_Square']
result['Mean_Absolute_Error_MAE']=Results['Mean_Absolute_Error_MAE']
result['Root_Mean_Squared_Error_RMSE']=Results['Root_Mean_Squared_Error_RMSE']
result['Mean_Absolute_Percentage_Error_MAPE']=Results['Mean_Absolute_Percentage_Error_MAPE']
result['Mean_Squared_Error_MSE']=Results['Mean_Squared_Error_MSE']
result['Root_Mean_Squared_Log_Error_RMSLE']=Results['Root_Mean_Squared_Log_Error_RMSLE']
result=result.sort_values(by='Adj_R_Square',ascending=False).reset_index(drop=True)
result
# Out:
#               Model_Name  R2_score  Adj_R_Square  Mean_Absolute_Error_MAE  \
# 0    ExtraTreesRegressor  0.991250      0.991250               805.213942
# 1  RandomForestRegressor  0.991247      0.991247               802.757557
# 2       LinearRegression  0.904425      0.904421              4668.562447
#
#    Root_Mean_Squared_Error_RMSE  Mean_Absolute_Percentage_Error_MAPE  \
# 0                   2120.467385                             5.436641
# 1                   2120.835855                             5.557894
# 2                   7007.988526                            44.695236
#
#    Mean_Squared_Error_MSE  Root_Mean_Squared_Log_Error_RMSLE
# 0            4.496382e+06                           7.659392
# 1            4.497945e+06                           7.659566
# 2            4.911190e+07                           8.854806

# %% [markdown]
# <p> From the Above Results, The 3 Models by comparing Errors , Adj_R_Square and R2_Score values are<br>
#
# 1. <b>LinearRegression</b>
# 2. <b>RandomForestRegressor</b>
# 3. <b>ExtraTreesRegressor</b><br>
#
# <p>Training the Data with <b>RandomForestRegressor</b></p>
# </p>

# %%
#Trainig the model with
modelrfr.fit(x_train, y_train)
    
# Predict the model with test data

y_pred = modelrfr.predict(x_test)

# %%
out=pd.DataFrame({'Price_actual':y_test,'Price_pred':y_pred})
result=df_bk.merge(out,left_index=True,right_index=True)

# %%
result.sample(10)
# Out:
#          index    airline source_city  duration stops destination_city  price  \
# 122970  123019   GO FIRST     Kolkata     750.0   one            Delhi   4549
# 161872  161925  Air India   Hyderabad     735.0   one           Mumbai   4363
# 101388  101395    Vistara   Bangalore     395.0   one           Mumbai   4792
# 299130  299232    Vistara     Chennai     680.0   one        Hyderabad  41064
# 200253  200355    AirAsia     Chennai     680.0   one          Kolkata   2361
# 99780    99787   GO FIRST   Bangalore     595.0   one           Mumbai   6389
# 215437  215539    Vistara       Delhi     810.0   one        Bangalore  62729
# 258423  258525  Air India   Bangalore     895.0   one        Hyderabad  56476
# 59887    59887  Air India      Mumbai     675.0   one        Bangalore   7833
# 292802  292904    Vistara     Chennai     560.0   one           Mumbai  64113
#
#            class dayOfWeek  days_left   flight departure_time   arrival_time  \
# 122970   Economy  Saturday         23   G8-125        Evening        Morning
# 161872   Economy    Monday         25   AI-840          Night        Morning
# 101388   Economy  Thursday         42   UK-897  Early Morning      Afternoon
# 299130  Business  Thursday         28   UK-824          Night  Early Morning
# 200253   Economy   Tuesday         26  I5-1727      Afternoon     Late Night
# 99780    Economy   Tuesday         33   G8-116  Early Morning        Evening
# 215437  Business    Friday         43   UK-975  Early Morning        Evening
# 258423  Business   Tuesday         40   AI-808          Night        Morning
# 59887    Economy   Tuesday         40   AI-673  Early Morning        Evening
# 292802  Business    Monday         39   UK-836        Morning          Night
#
#         Price_actual  Price_pred
# 122970          4549     5113.00
# 161872          4363     4671.65
# 101388          4792     4792.00
# 299130         41064    41064.00
# 200253          2361     2361.00
# 99780           6389     6389.00
# 215437         62729    60808.20
# 258423         56476    56476.00
# 59887           7833     9422.68
# 292802         64113    66995.35

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=result,x='days_left',y='Price_actual',color='red')
sb.lineplot(data=result,x='days_left',y='Price_pred',color='blue')
plt.title('Days Left For Departure Versus Actual Ticket Price and Predicted Ticket Price',fontsize=20)
plt.legend(labels=['Price actual','Price actual range', 'Price predicted', 'Price predicted range'],fontsize=19)
plt.xlabel('Days Left for Departure',fontsize=15)
plt.ylabel('Actual and Predicted Price',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=result,x='source_city',y='Price_actual',color='red')
sb.lineplot(data=result,x='source_city',y='Price_pred',color='blue')
plt.title('Source City Versus Actual Ticket Price and Predicted Ticket Price',fontsize=20)
plt.legend(labels=['Price actual','Price actual range', 'Price predicted', 'Price predicted range'],fontsize=19)
plt.xlabel('Days Left for Departure',fontsize=15)
plt.ylabel('Actual and Predicted Price',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
sb.regplot(x='Price_actual',y='Price_pred',data=result,color='cyan')
plt.title('Actual Price  Vs  Predicted Price ',fontsize=20)
plt.xlabel('Actual Price',fontsize=15)
plt.ylabel('Predicted Price',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=result,x='departure_time',y='Price_pred',hue='dayOfWeek',palette='hls')
plt.title('Predicted Price Versus Departure Time based on Day of Week',fontsize=20)
plt.xlabel('Departure Period',fontsize=15)
plt.ylabel('Predicted Price',fontsize=15)
plt.show()
